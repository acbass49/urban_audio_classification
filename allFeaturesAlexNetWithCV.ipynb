# %% [markdown]
# # AlexNet - All Features - With 10 Crossfold Validation

# %% [markdown]
# ## Set up

# %%
### Load necessary libraries ###
import glob
import os
import librosa
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPool2D, Dropout

import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm

from librosa import display
import librosa
# Out:
# 2022-12-01 20:17:28.561526: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train_data = pd.read_csv("allFeaturesData/train_data.csv", header = None)
test_data = pd.read_csv("allFeaturesData/test_data.csv", header = None)
train_lab = pd.read_csv("allFeaturesData/train_labels.csv", header = None)
test_lab = pd.read_csv("allFeaturesData/test_labels.csv", header = None)

# %%
len(train_data)+len(test_data)
# Out:
# 8732

# %%
X=pd.concat([train_data, test_data]) # .to_numpy().reshape(8732, 40, 5, 1)
Y=pd.concat([train_lab,test_lab]) # .to_numpy().reshape(8732,)

# %%
folds = pd.read_csv("allFeaturesData/All_folds.csv", header=None)
folds.columns = ['folds']
folds['folds'] = folds['folds'].astype('int')

# %%
### Train and evaluate via 10-Folds cross-validation ###
keras.backend.clear_session()
accuracies = []

for i in range(1, 11):  # 1-10 to match values in folds df
    # obtain train and test indices
    test_idx = list(np.where(folds['folds'] == i)[0]) # find all indices for fold i and set as test indices
    train_idx = list(np.setdiff1d(folds.index.to_numpy(), np.where(folds['folds'] == i)[0])) # everything except fold i as train indices

    # use train and test indices to create train and test x/y and reshape them for training our model
    x_train = X.iloc[train_idx].to_numpy().reshape(len(train_idx), 40, 5, 1)
    y_train = Y.iloc[train_idx].to_numpy().reshape(len(train_idx),)
    x_test = X.iloc[test_idx].to_numpy().reshape(len(test_idx), 40, 5, 1)
    y_test = Y.iloc[test_idx].to_numpy().reshape(len(test_idx),)

    # insert model architecture here (just put the alexnet for reference, will need to update this for each model)
    pool_size = (2, 2)
    kernel_size = (3, 3)
    input_shape = (40, 5, 1)
    num_classes = 10

    model = Sequential()
    model.add(Conv2D(64, (3, 3), padding = "same", activation = "tanh", input_shape = input_shape))
    model.add(MaxPool2D(pool_size=(2, 2)))
    model.add(Conv2D(128, (3, 3), padding = "same", activation = "tanh"))
    model.add(MaxPool2D(pool_size=(2, 2)))
    model.add(Dropout(0.1))
    model.add(Flatten())
    model.add(Dense(1024, activation = "tanh"))
    model.add(Dense(10, activation = "softmax"))

    optimizer = keras.optimizers.Adam(lr=1e-4)
    model.compile(optimizer = optimizer, loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
    model.fit(x_train, y_train, epochs = 50, batch_size = 50, validation_data = (x_test, y_test))


    # add accuracy to our accuracies list for comparison
    accuracies.append(model.evaluate(x_test, y_test)[1])
    # index 0 is validation loss in final epoch, index 1 is validation accuracy in final epoch
    # if we try and look into other metrics, they may be in a different index and 
    # we would need ot make a separate list for those metrics
# Out:
# 2022-12-01 20:27:05.737662: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/50
# 158/158 [==============================] - 5s 25ms/step - loss: 1.6624 - accuracy: 0.4526 - val_loss: 1.4423 - val_accuracy: 0.5842
# Epoch 2/50
# 158/158 [==============================] - 3s 22ms/step - loss: 1.1088 - accuracy: 0.6432 - val_loss: 1.2846 - val_accuracy: 0.6151
# Epoch 3/50
# 158/158 [==============================] - 3s 22ms/step - loss: 0.8644 - accuracy: 0.7320 - val_loss: 1.3050 - val_accuracy: 0.6220
# Epoch 4/50
# 158/158 [==============================] - 4s 22ms/step - loss: 0.7169 - accuracy: 0.7811 - val_loss: 1.3562 - val_accuracy: 0.6231
# Epoch 5/50
# 158/158 [==============================] - 3s 22ms/step - loss: 0.6142 - accuracy: 0.8140 - val_loss: 1.3911 - val_accuracy: 0.6128
# Epoch 6/50
# 158/158 [==============================] - 4s 22ms/step - loss: 0.5373 - accuracy: 0.8365 - val_loss: 1.4801 - val_accuracy: 0.6208
# Epoch 7/50
# 158/158 [==============================] - 4s 22ms/step - loss: 0.4714 - accuracy: 0.8589 - val_loss: 1.5000 - val_accuracy: 0.6174
# Epoch 8/50
# 158/158 [==============================] - 3s 22ms/step - loss: 0.4192 - accuracy: 0.8772 - val_loss: 1.5986 - val_accuracy: 0.5991
# Epoch 9/50
# 158/158 [==============================] - 3s 22ms/step - loss: 0.3782 - accuracy: 0.8856 - val_loss: 1.5727 - val_accuracy: 0.6231
# Epoch 10/50
# 158/158 [==============================] - 4s 23ms/step - loss: 0.3405 - accuracy: 0.8973 - val_loss: 1.6753 - val_accuracy: 0.6117
# Epoch 11/50
# 158/158 [==============================] - 4s 22ms/step - loss: 0.3127 - accuracy: 0.9052 - val_loss: 1.7440 - val_accuracy: 0.5968
# Epoch 12/50
# 158/158 [==============================] - 4s 24ms/step - loss: 0.2811 - accuracy: 0.9175 - val_loss: 1.8603 - val_accuracy: 0.5773
# Epoch 13/50
# 158/158 [==============================] - 4s 26ms/step - loss: 0.2585 - accuracy: 0.9252 - val_loss: 1.7880 - val_accuracy: 0.5945
# Epoch 14/50
# 158/158 [==============================] - 4s 25ms/step - loss: 0.2323 - accuracy: 0.9285 - val_loss: 1.8389 - val_accuracy: 0.5979
# Epoch 15/50
# 158/158 [==============================] - 5s 30ms/step - loss: 0.2163 - accuracy: 0.9350 - val_loss: 1.9086 - val_accuracy: 0.5899
# Epoch 16/50
# 158/158 [==============================] - 4s 24ms/step - loss: 0.1981 - accuracy: 0.9396 - val_loss: 1.9585 - val_accuracy: 0.5922
# Epoch 17/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.1835 - accuracy: 0.9464 - val_loss: 2.0966 - val_accuracy: 0.5796
# Epoch 18/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.1696 - accuracy: 0.9500 - val_loss: 2.2279 - val_accuracy: 0.5670
# Epoch 19/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.1588 - accuracy: 0.9528 - val_loss: 2.0757 - val_accuracy: 0.5853
# Epoch 20/50
# 158/158 [==============================] - 4s 23ms/step - loss: 0.1413 - accuracy: 0.9595 - val_loss: 2.0866 - val_accuracy: 0.5762
# Epoch 21/50
# 158/158 [==============================] - 4s 27ms/step - loss: 0.1323 - accuracy: 0.9626 - val_loss: 2.0988 - val_accuracy: 0.5842
# Epoch 22/50
# 158/158 [==============================] - 4s 23ms/step - loss: 0.1271 - accuracy: 0.9631 - val_loss: 2.2365 - val_accuracy: 0.5716
# Epoch 23/50
# 158/158 [==============================] - 4s 22ms/step - loss: 0.1134 - accuracy: 0.9692 - val_loss: 2.3142 - val_accuracy: 0.5727
# Epoch 24/50
# 158/158 [==============================] - 4s 22ms/step - loss: 0.1036 - accuracy: 0.9724 - val_loss: 2.4748 - val_accuracy: 0.5785
# Epoch 25/50
# 158/158 [==============================] - 4s 23ms/step - loss: 0.1006 - accuracy: 0.9723 - val_loss: 2.5157 - val_accuracy: 0.5636
# Epoch 26/50
# 158/158 [==============================] - 4s 23ms/step - loss: 0.0939 - accuracy: 0.9754 - val_loss: 2.4840 - val_accuracy: 0.5624
# Epoch 27/50
# 158/158 [==============================] - 4s 23ms/step - loss: 0.0815 - accuracy: 0.9786 - val_loss: 2.6176 - val_accuracy: 0.5613
# Epoch 28/50
# 158/158 [==============================] - 4s 23ms/step - loss: 0.0835 - accuracy: 0.9768 - val_loss: 2.7319 - val_accuracy: 0.5636
# Epoch 29/50
# 158/158 [==============================] - 4s 23ms/step - loss: 0.0779 - accuracy: 0.9782 - val_loss: 2.5524 - val_accuracy: 0.5670
# Epoch 30/50
# 158/158 [==============================] - 4s 23ms/step - loss: 0.0667 - accuracy: 0.9836 - val_loss: 2.6056 - val_accuracy: 0.5716
# Epoch 31/50
# 158/158 [==============================] - 4s 23ms/step - loss: 0.0671 - accuracy: 0.9817 - val_loss: 2.7835 - val_accuracy: 0.5647
# Epoch 32/50
# 158/158 [==============================] - 4s 23ms/step - loss: 0.0563 - accuracy: 0.9860 - val_loss: 2.7730 - val_accuracy: 0.5624
# Epoch 33/50
# 158/158 [==============================] - 4s 23ms/step - loss: 0.0591 - accuracy: 0.9828 - val_loss: 2.8568 - val_accuracy: 0.5533
# Epoch 34/50
# 158/158 [==============================] - 4s 23ms/step - loss: 0.0535 - accuracy: 0.9857 - val_loss: 2.8873 - val_accuracy: 0.5544
# Epoch 35/50
# 158/158 [==============================] - 4s 23ms/step - loss: 0.0470 - accuracy: 0.9898 - val_loss: 2.7806 - val_accuracy: 0.5682
# Epoch 36/50
# 158/158 [==============================] - 4s 24ms/step - loss: 0.0440 - accuracy: 0.9897 - val_loss: 2.8743 - val_accuracy: 0.5613
# Epoch 37/50
# 158/158 [==============================] - 4s 24ms/step - loss: 0.0435 - accuracy: 0.9892 - val_loss: 2.8561 - val_accuracy: 0.5578
# Epoch 38/50
# 158/158 [==============================] - 4s 24ms/step - loss: 0.0428 - accuracy: 0.9908 - val_loss: 2.7800 - val_accuracy: 0.5727
# Epoch 39/50
# 158/158 [==============================] - 4s 23ms/step - loss: 0.0414 - accuracy: 0.9892 - val_loss: 3.0267 - val_accuracy: 0.5659
# Epoch 40/50
# 158/158 [==============================] - 4s 24ms/step - loss: 0.0397 - accuracy: 0.9889 - val_loss: 2.8671 - val_accuracy: 0.5785
# Epoch 41/50
# 158/158 [==============================] - 4s 24ms/step - loss: 0.0348 - accuracy: 0.9916 - val_loss: 3.1006 - val_accuracy: 0.5395
# Epoch 42/50
# 158/158 [==============================] - 4s 24ms/step - loss: 0.0374 - accuracy: 0.9903 - val_loss: 3.3676 - val_accuracy: 0.5430
# Epoch 43/50
# 158/158 [==============================] - 4s 24ms/step - loss: 0.0317 - accuracy: 0.9933 - val_loss: 3.4109 - val_accuracy: 0.5613
# Epoch 44/50
# 158/158 [==============================] - 4s 24ms/step - loss: 0.0337 - accuracy: 0.9926 - val_loss: 3.2011 - val_accuracy: 0.5590
# Epoch 45/50
# 158/158 [==============================] - 4s 24ms/step - loss: 0.0288 - accuracy: 0.9931 - val_loss: 3.1265 - val_accuracy: 0.5533
# Epoch 46/50
# 158/158 [==============================] - 4s 23ms/step - loss: 0.0252 - accuracy: 0.9943 - val_loss: 3.2718 - val_accuracy: 0.5487
# Epoch 47/50
# 158/158 [==============================] - 4s 24ms/step - loss: 0.0268 - accuracy: 0.9941 - val_loss: 3.6474 - val_accuracy: 0.5441
# Epoch 48/50
# 158/158 [==============================] - 4s 24ms/step - loss: 0.0266 - accuracy: 0.9936 - val_loss: 3.2733 - val_accuracy: 0.5647
# Epoch 49/50
# 158/158 [==============================] - 4s 23ms/step - loss: 0.0335 - accuracy: 0.9908 - val_loss: 3.0663 - val_accuracy: 0.5682
# Epoch 50/50
# 158/158 [==============================] - 4s 23ms/step - loss: 0.0248 - accuracy: 0.9938 - val_loss: 3.4079 - val_accuracy: 0.5613
# 28/28 [==============================] - 0s 6ms/step - loss: 3.4079 - accuracy: 0.5613
# Epoch 1/50
# 157/157 [==============================] - 4s 25ms/step - loss: 1.6637 - accuracy: 0.4600 - val_loss: 1.4103 - val_accuracy: 0.5068
# Epoch 2/50
# 157/157 [==============================] - 4s 24ms/step - loss: 1.1268 - accuracy: 0.6336 - val_loss: 1.2339 - val_accuracy: 0.5743
# Epoch 3/50
# 157/157 [==============================] - 4s 25ms/step - loss: 0.8921 - accuracy: 0.7193 - val_loss: 1.1941 - val_accuracy: 0.5552
# Epoch 4/50
# 157/157 [==============================] - 4s 25ms/step - loss: 0.7440 - accuracy: 0.7729 - val_loss: 1.2127 - val_accuracy: 0.6059
# Epoch 5/50
# 157/157 [==============================] - 4s 25ms/step - loss: 0.6392 - accuracy: 0.8048 - val_loss: 1.2260 - val_accuracy: 0.5608
# Epoch 6/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.5626 - accuracy: 0.8275 - val_loss: 1.2825 - val_accuracy: 0.5755
# Epoch 7/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.5028 - accuracy: 0.8463 - val_loss: 1.3685 - val_accuracy: 0.5822
# Epoch 8/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.4579 - accuracy: 0.8614 - val_loss: 1.2695 - val_accuracy: 0.5631
# Epoch 9/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.4051 - accuracy: 0.8783 - val_loss: 1.3859 - val_accuracy: 0.5664
# Epoch 10/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.3768 - accuracy: 0.8821 - val_loss: 1.4890 - val_accuracy: 0.5417
# Epoch 11/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.3445 - accuracy: 0.8937 - val_loss: 1.5024 - val_accuracy: 0.5743
# Epoch 12/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.3183 - accuracy: 0.9029 - val_loss: 1.4492 - val_accuracy: 0.5586
# Epoch 13/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.2889 - accuracy: 0.9113 - val_loss: 1.5580 - val_accuracy: 0.5743
# Epoch 14/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.2676 - accuracy: 0.9198 - val_loss: 1.6286 - val_accuracy: 0.5709
# Epoch 15/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.2547 - accuracy: 0.9225 - val_loss: 1.4879 - val_accuracy: 0.5800
# Epoch 16/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.2307 - accuracy: 0.9290 - val_loss: 1.6159 - val_accuracy: 0.5586
# Epoch 17/50
# 157/157 [==============================] - 4s 25ms/step - loss: 0.2100 - accuracy: 0.9369 - val_loss: 1.5853 - val_accuracy: 0.5788
# Epoch 18/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.1988 - accuracy: 0.9392 - val_loss: 1.6337 - val_accuracy: 0.5822
# Epoch 19/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.1882 - accuracy: 0.9421 - val_loss: 1.7113 - val_accuracy: 0.5878
# Epoch 20/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.1727 - accuracy: 0.9499 - val_loss: 1.6942 - val_accuracy: 0.5811
# Epoch 21/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.1570 - accuracy: 0.9549 - val_loss: 1.7396 - val_accuracy: 0.5935
# Epoch 22/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.1530 - accuracy: 0.9546 - val_loss: 1.7142 - val_accuracy: 0.5980
# Epoch 23/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.1395 - accuracy: 0.9589 - val_loss: 1.8384 - val_accuracy: 0.5935
# Epoch 24/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.1280 - accuracy: 0.9652 - val_loss: 1.7326 - val_accuracy: 0.5822
# Epoch 25/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.1204 - accuracy: 0.9665 - val_loss: 1.8575 - val_accuracy: 0.5833
# Epoch 26/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.1188 - accuracy: 0.9669 - val_loss: 1.8375 - val_accuracy: 0.5856
# Epoch 27/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.1042 - accuracy: 0.9720 - val_loss: 2.0017 - val_accuracy: 0.6036
# Epoch 28/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.0979 - accuracy: 0.9741 - val_loss: 1.9308 - val_accuracy: 0.5968
# Epoch 29/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.0923 - accuracy: 0.9760 - val_loss: 1.9422 - val_accuracy: 0.5957
# Epoch 30/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.0896 - accuracy: 0.9748 - val_loss: 2.1749 - val_accuracy: 0.5935
# Epoch 31/50
# 157/157 [==============================] - 4s 25ms/step - loss: 0.0891 - accuracy: 0.9741 - val_loss: 1.9020 - val_accuracy: 0.6002
# Epoch 32/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.0770 - accuracy: 0.9801 - val_loss: 2.1111 - val_accuracy: 0.6002
# Epoch 33/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.0755 - accuracy: 0.9793 - val_loss: 1.9924 - val_accuracy: 0.5867
# Epoch 34/50
# 157/157 [==============================] - 4s 25ms/step - loss: 0.0711 - accuracy: 0.9814 - val_loss: 2.0270 - val_accuracy: 0.6014
# Epoch 35/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.0630 - accuracy: 0.9846 - val_loss: 2.1368 - val_accuracy: 0.5878
# Epoch 36/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.0673 - accuracy: 0.9810 - val_loss: 2.2547 - val_accuracy: 0.6036
# Epoch 37/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.0579 - accuracy: 0.9838 - val_loss: 2.5213 - val_accuracy: 0.5833
# Epoch 38/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.0536 - accuracy: 0.9861 - val_loss: 2.3526 - val_accuracy: 0.6014
# Epoch 39/50
# 157/157 [==============================] - 4s 25ms/step - loss: 0.0496 - accuracy: 0.9865 - val_loss: 2.2885 - val_accuracy: 0.5957
# Epoch 40/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.0474 - accuracy: 0.9883 - val_loss: 2.2871 - val_accuracy: 0.5968
# Epoch 41/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.0448 - accuracy: 0.9903 - val_loss: 2.3380 - val_accuracy: 0.6137
# Epoch 42/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.0419 - accuracy: 0.9889 - val_loss: 2.3308 - val_accuracy: 0.5980
# Epoch 43/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.0431 - accuracy: 0.9888 - val_loss: 2.4200 - val_accuracy: 0.6014
# Epoch 44/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.0379 - accuracy: 0.9908 - val_loss: 2.7221 - val_accuracy: 0.5901
# Epoch 45/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.0394 - accuracy: 0.9904 - val_loss: 2.7868 - val_accuracy: 0.6014
# Epoch 46/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.0385 - accuracy: 0.9904 - val_loss: 2.6288 - val_accuracy: 0.5856
# Epoch 47/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.0339 - accuracy: 0.9921 - val_loss: 2.5071 - val_accuracy: 0.5946
# Epoch 48/50
# 157/157 [==============================] - 4s 25ms/step - loss: 0.0320 - accuracy: 0.9926 - val_loss: 2.5556 - val_accuracy: 0.6025
# Epoch 49/50
# 157/157 [==============================] - 4s 25ms/step - loss: 0.0331 - accuracy: 0.9917 - val_loss: 2.5670 - val_accuracy: 0.6025
# Epoch 50/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.0300 - accuracy: 0.9932 - val_loss: 2.5968 - val_accuracy: 0.6047
# 28/28 [==============================] - 0s 6ms/step - loss: 2.5968 - accuracy: 0.6047
# Epoch 1/50
# 157/157 [==============================] - 4s 25ms/step - loss: 1.6656 - accuracy: 0.4572 - val_loss: 1.4256 - val_accuracy: 0.4951
# Epoch 2/50
# 157/157 [==============================] - 4s 25ms/step - loss: 1.1167 - accuracy: 0.6412 - val_loss: 1.3192 - val_accuracy: 0.5243
# Epoch 3/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.8948 - accuracy: 0.7187 - val_loss: 1.2651 - val_accuracy: 0.5373
# Epoch 4/50
# 157/157 [==============================] - 4s 25ms/step - loss: 0.7471 - accuracy: 0.7667 - val_loss: 1.2937 - val_accuracy: 0.5362
# Epoch 5/50
# 157/157 [==============================] - 4s 25ms/step - loss: 0.6361 - accuracy: 0.8082 - val_loss: 1.3022 - val_accuracy: 0.5438
# Epoch 6/50
# 157/157 [==============================] - 4s 25ms/step - loss: 0.5602 - accuracy: 0.8278 - val_loss: 1.2777 - val_accuracy: 0.5330
# Epoch 7/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.4908 - accuracy: 0.8504 - val_loss: 1.3394 - val_accuracy: 0.5546
# Epoch 8/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.4416 - accuracy: 0.8649 - val_loss: 1.3805 - val_accuracy: 0.5481
# Epoch 9/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.3988 - accuracy: 0.8787 - val_loss: 1.4008 - val_accuracy: 0.5600
# Epoch 10/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.3629 - accuracy: 0.8909 - val_loss: 1.4246 - val_accuracy: 0.5546
# Epoch 11/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.3269 - accuracy: 0.8996 - val_loss: 1.3929 - val_accuracy: 0.5492
# Epoch 12/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.3010 - accuracy: 0.9094 - val_loss: 1.4115 - val_accuracy: 0.5600
# Epoch 13/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.2747 - accuracy: 0.9183 - val_loss: 1.4276 - val_accuracy: 0.5773
# Epoch 14/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.2545 - accuracy: 0.9242 - val_loss: 1.4755 - val_accuracy: 0.5557
# Epoch 15/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.2357 - accuracy: 0.9285 - val_loss: 1.5314 - val_accuracy: 0.5535
# Epoch 16/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.2222 - accuracy: 0.9336 - val_loss: 1.5177 - val_accuracy: 0.5589
# Epoch 17/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.2084 - accuracy: 0.9385 - val_loss: 1.5695 - val_accuracy: 0.5622
# Epoch 18/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.1915 - accuracy: 0.9435 - val_loss: 1.5292 - val_accuracy: 0.5643
# Epoch 19/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.1766 - accuracy: 0.9477 - val_loss: 1.5829 - val_accuracy: 0.5719
# Epoch 20/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.1679 - accuracy: 0.9516 - val_loss: 1.6395 - val_accuracy: 0.5568
# Epoch 21/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.1560 - accuracy: 0.9536 - val_loss: 1.8604 - val_accuracy: 0.5481
# Epoch 22/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.1458 - accuracy: 0.9570 - val_loss: 1.7064 - val_accuracy: 0.5611
# Epoch 23/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.1369 - accuracy: 0.9600 - val_loss: 1.7919 - val_accuracy: 0.5578
# Epoch 24/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.1298 - accuracy: 0.9616 - val_loss: 1.7421 - val_accuracy: 0.5751
# Epoch 25/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.1176 - accuracy: 0.9654 - val_loss: 1.8586 - val_accuracy: 0.5427
# Epoch 26/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.1125 - accuracy: 0.9684 - val_loss: 1.6993 - val_accuracy: 0.5784
# Epoch 27/50
# 157/157 [==============================] - 4s 22ms/step - loss: 0.1077 - accuracy: 0.9704 - val_loss: 1.8697 - val_accuracy: 0.5514
# Epoch 28/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.0964 - accuracy: 0.9740 - val_loss: 1.9062 - val_accuracy: 0.5395
# Epoch 29/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.0990 - accuracy: 0.9717 - val_loss: 1.8496 - val_accuracy: 0.5665
# Epoch 30/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.0926 - accuracy: 0.9732 - val_loss: 1.8374 - val_accuracy: 0.5730
# Epoch 31/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.0771 - accuracy: 0.9810 - val_loss: 1.9471 - val_accuracy: 0.5568
# Epoch 32/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.0774 - accuracy: 0.9786 - val_loss: 2.0203 - val_accuracy: 0.5546
# Epoch 33/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.0729 - accuracy: 0.9810 - val_loss: 2.0515 - val_accuracy: 0.5708
# Epoch 34/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.0686 - accuracy: 0.9837 - val_loss: 2.0341 - val_accuracy: 0.5730
# Epoch 35/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.0683 - accuracy: 0.9808 - val_loss: 1.9984 - val_accuracy: 0.5503
# Epoch 36/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.0646 - accuracy: 0.9821 - val_loss: 2.1505 - val_accuracy: 0.5351
# Epoch 37/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.0591 - accuracy: 0.9855 - val_loss: 2.1937 - val_accuracy: 0.5351
# Epoch 38/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.0552 - accuracy: 0.9858 - val_loss: 2.1620 - val_accuracy: 0.5438
# Epoch 39/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.0481 - accuracy: 0.9877 - val_loss: 2.1778 - val_accuracy: 0.5859
# Epoch 40/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.0507 - accuracy: 0.9874 - val_loss: 2.1744 - val_accuracy: 0.5308
# Epoch 41/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.0463 - accuracy: 0.9885 - val_loss: 2.3637 - val_accuracy: 0.5232
# Epoch 42/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.0489 - accuracy: 0.9863 - val_loss: 2.4222 - val_accuracy: 0.5405
# Epoch 43/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.0449 - accuracy: 0.9874 - val_loss: 2.3312 - val_accuracy: 0.5308
# Epoch 44/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.0384 - accuracy: 0.9896 - val_loss: 2.3497 - val_accuracy: 0.5503
# Epoch 45/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.0407 - accuracy: 0.9892 - val_loss: 2.2300 - val_accuracy: 0.5546
# Epoch 46/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.0406 - accuracy: 0.9883 - val_loss: 2.4564 - val_accuracy: 0.5676
# Epoch 47/50
# 157/157 [==============================] - 4s 23ms/step - loss: 0.0356 - accuracy: 0.9918 - val_loss: 2.4080 - val_accuracy: 0.5546
# Epoch 48/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.0360 - accuracy: 0.9894 - val_loss: 2.4132 - val_accuracy: 0.5654
# Epoch 49/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.0335 - accuracy: 0.9908 - val_loss: 2.4822 - val_accuracy: 0.5535
# Epoch 50/50
# 157/157 [==============================] - 4s 24ms/step - loss: 0.0314 - accuracy: 0.9912 - val_loss: 2.5809 - val_accuracy: 0.5276
# 29/29 [==============================] - 0s 5ms/step - loss: 2.5809 - accuracy: 0.5276
# Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 1.6963 - accuracy: 0.4326 - val_loss: 1.4415 - val_accuracy: 0.5495
# Epoch 2/50
# 155/155 [==============================] - 4s 24ms/step - loss: 1.1595 - accuracy: 0.6239 - val_loss: 1.2473 - val_accuracy: 0.5747
# Epoch 3/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.9257 - accuracy: 0.7090 - val_loss: 1.1578 - val_accuracy: 0.6010
# Epoch 4/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.7614 - accuracy: 0.7650 - val_loss: 1.1775 - val_accuracy: 0.5919
# Epoch 5/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.6455 - accuracy: 0.8026 - val_loss: 1.0686 - val_accuracy: 0.6394
# Epoch 6/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.5639 - accuracy: 0.8281 - val_loss: 1.0685 - val_accuracy: 0.6253
# Epoch 7/50
# 155/155 [==============================] - 4s 26ms/step - loss: 0.4982 - accuracy: 0.8484 - val_loss: 1.0484 - val_accuracy: 0.6111
# Epoch 8/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.4549 - accuracy: 0.8610 - val_loss: 1.1134 - val_accuracy: 0.6091
# Epoch 9/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.4078 - accuracy: 0.8779 - val_loss: 1.0557 - val_accuracy: 0.6444
# Epoch 10/50
# 155/155 [==============================] - 4s 23ms/step - loss: 0.3633 - accuracy: 0.8910 - val_loss: 1.0398 - val_accuracy: 0.6303
# Epoch 11/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.3311 - accuracy: 0.8989 - val_loss: 1.1424 - val_accuracy: 0.6051
# Epoch 12/50
# 155/155 [==============================] - 4s 23ms/step - loss: 0.3110 - accuracy: 0.9048 - val_loss: 1.0665 - val_accuracy: 0.6576
# Epoch 13/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.2807 - accuracy: 0.9151 - val_loss: 1.1514 - val_accuracy: 0.5929
# Epoch 14/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.2599 - accuracy: 0.9204 - val_loss: 1.0567 - val_accuracy: 0.6485
# Epoch 15/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.2424 - accuracy: 0.9279 - val_loss: 1.0841 - val_accuracy: 0.6606
# Epoch 16/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.2277 - accuracy: 0.9317 - val_loss: 1.1295 - val_accuracy: 0.6374
# Epoch 17/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.2066 - accuracy: 0.9386 - val_loss: 1.1755 - val_accuracy: 0.6303
# Epoch 18/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.1937 - accuracy: 0.9407 - val_loss: 1.1162 - val_accuracy: 0.6465
# Epoch 19/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.1736 - accuracy: 0.9491 - val_loss: 1.2208 - val_accuracy: 0.6141
# Epoch 20/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.1658 - accuracy: 0.9538 - val_loss: 1.1717 - val_accuracy: 0.6444
# Epoch 21/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.1576 - accuracy: 0.9538 - val_loss: 1.2328 - val_accuracy: 0.6232
# Epoch 22/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.1420 - accuracy: 0.9588 - val_loss: 1.3150 - val_accuracy: 0.5919
# Epoch 23/50
# 155/155 [==============================] - 4s 23ms/step - loss: 0.1305 - accuracy: 0.9616 - val_loss: 1.3113 - val_accuracy: 0.5990
# Epoch 24/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.1212 - accuracy: 0.9667 - val_loss: 1.1855 - val_accuracy: 0.6626
# Epoch 25/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.1206 - accuracy: 0.9654 - val_loss: 1.2409 - val_accuracy: 0.6374
# Epoch 26/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.1090 - accuracy: 0.9682 - val_loss: 1.2672 - val_accuracy: 0.6374
# Epoch 27/50
# 155/155 [==============================] - 4s 23ms/step - loss: 0.1021 - accuracy: 0.9720 - val_loss: 1.4180 - val_accuracy: 0.5889
# Epoch 28/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.1031 - accuracy: 0.9702 - val_loss: 1.3731 - val_accuracy: 0.6273
# Epoch 29/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.0911 - accuracy: 0.9749 - val_loss: 1.3396 - val_accuracy: 0.6020
# Epoch 30/50
# 155/155 [==============================] - 4s 23ms/step - loss: 0.0851 - accuracy: 0.9761 - val_loss: 1.3878 - val_accuracy: 0.6364
# Epoch 31/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.0766 - accuracy: 0.9792 - val_loss: 1.4653 - val_accuracy: 0.6051
# Epoch 32/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0758 - accuracy: 0.9805 - val_loss: 1.4915 - val_accuracy: 0.5949
# Epoch 33/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0673 - accuracy: 0.9844 - val_loss: 1.4108 - val_accuracy: 0.6465
# Epoch 34/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.0654 - accuracy: 0.9835 - val_loss: 1.5066 - val_accuracy: 0.5869
# Epoch 35/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.0624 - accuracy: 0.9827 - val_loss: 1.6128 - val_accuracy: 0.5889
# Epoch 36/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.0572 - accuracy: 0.9859 - val_loss: 1.5507 - val_accuracy: 0.6071
# Epoch 37/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.0535 - accuracy: 0.9858 - val_loss: 1.5975 - val_accuracy: 0.6000
# Epoch 38/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.0586 - accuracy: 0.9848 - val_loss: 1.4814 - val_accuracy: 0.6253
# Epoch 39/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.0514 - accuracy: 0.9862 - val_loss: 1.6301 - val_accuracy: 0.6010
# Epoch 40/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.0468 - accuracy: 0.9882 - val_loss: 1.6178 - val_accuracy: 0.6162
# Epoch 41/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.0486 - accuracy: 0.9859 - val_loss: 1.8440 - val_accuracy: 0.5576
# Epoch 42/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.0438 - accuracy: 0.9885 - val_loss: 1.5926 - val_accuracy: 0.6101
# Epoch 43/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.0414 - accuracy: 0.9892 - val_loss: 1.5854 - val_accuracy: 0.6111
# Epoch 44/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.0390 - accuracy: 0.9902 - val_loss: 1.5565 - val_accuracy: 0.6131
# Epoch 45/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.0413 - accuracy: 0.9879 - val_loss: 1.8166 - val_accuracy: 0.6040
# Epoch 46/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0383 - accuracy: 0.9913 - val_loss: 1.8383 - val_accuracy: 0.6131
# Epoch 47/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.0346 - accuracy: 0.9912 - val_loss: 1.7484 - val_accuracy: 0.6162
# Epoch 48/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0311 - accuracy: 0.9925 - val_loss: 1.8033 - val_accuracy: 0.6051
# Epoch 49/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.0303 - accuracy: 0.9928 - val_loss: 1.7531 - val_accuracy: 0.5980
# Epoch 50/50
# 155/155 [==============================] - 4s 26ms/step - loss: 0.0315 - accuracy: 0.9919 - val_loss: 1.7086 - val_accuracy: 0.6323
# 31/31 [==============================] - 0s 5ms/step - loss: 1.7086 - accuracy: 0.6323
# Epoch 1/50
# 156/156 [==============================] - 4s 25ms/step - loss: 1.6656 - accuracy: 0.4515 - val_loss: 1.5122 - val_accuracy: 0.4541
# Epoch 2/50
# 156/156 [==============================] - 4s 25ms/step - loss: 1.1336 - accuracy: 0.6375 - val_loss: 1.3539 - val_accuracy: 0.5470
# Epoch 3/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.9131 - accuracy: 0.7174 - val_loss: 1.2970 - val_accuracy: 0.5726
# Epoch 4/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.7650 - accuracy: 0.7637 - val_loss: 1.2574 - val_accuracy: 0.5823
# Epoch 5/50
# 156/156 [==============================] - 4s 25ms/step - loss: 0.6547 - accuracy: 0.8058 - val_loss: 1.2537 - val_accuracy: 0.5994
# Epoch 6/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.5749 - accuracy: 0.8275 - val_loss: 1.1950 - val_accuracy: 0.6250
# Epoch 7/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.5056 - accuracy: 0.8459 - val_loss: 1.2414 - val_accuracy: 0.6239
# Epoch 8/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.4603 - accuracy: 0.8593 - val_loss: 1.2307 - val_accuracy: 0.6325
# Epoch 9/50
# 156/156 [==============================] - 4s 23ms/step - loss: 0.4117 - accuracy: 0.8766 - val_loss: 1.2368 - val_accuracy: 0.6506
# Epoch 10/50
# 156/156 [==============================] - 4s 23ms/step - loss: 0.3742 - accuracy: 0.8843 - val_loss: 1.2413 - val_accuracy: 0.6421
# Epoch 11/50
# 156/156 [==============================] - 4s 23ms/step - loss: 0.3407 - accuracy: 0.8971 - val_loss: 1.3474 - val_accuracy: 0.6378
# Epoch 12/50
# 156/156 [==============================] - 4s 25ms/step - loss: 0.3158 - accuracy: 0.9032 - val_loss: 1.3056 - val_accuracy: 0.6421
# Epoch 13/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.2945 - accuracy: 0.9088 - val_loss: 1.3767 - val_accuracy: 0.6271
# Epoch 14/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.2660 - accuracy: 0.9165 - val_loss: 1.3240 - val_accuracy: 0.6368
# Epoch 15/50
# 156/156 [==============================] - 4s 25ms/step - loss: 0.2441 - accuracy: 0.9274 - val_loss: 1.2627 - val_accuracy: 0.6506
# Epoch 16/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.2246 - accuracy: 0.9343 - val_loss: 1.3335 - val_accuracy: 0.6453
# Epoch 17/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.2129 - accuracy: 0.9348 - val_loss: 1.4224 - val_accuracy: 0.6271
# Epoch 18/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.1985 - accuracy: 0.9407 - val_loss: 1.5066 - val_accuracy: 0.6175
# Epoch 19/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.1802 - accuracy: 0.9454 - val_loss: 1.4907 - val_accuracy: 0.6464
# Epoch 20/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.1665 - accuracy: 0.9502 - val_loss: 1.4514 - val_accuracy: 0.6400
# Epoch 21/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.1575 - accuracy: 0.9541 - val_loss: 1.5216 - val_accuracy: 0.6538
# Epoch 22/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.1490 - accuracy: 0.9542 - val_loss: 1.6111 - val_accuracy: 0.6400
# Epoch 23/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.1367 - accuracy: 0.9602 - val_loss: 1.5049 - val_accuracy: 0.6378
# Epoch 24/50
# 156/156 [==============================] - 4s 25ms/step - loss: 0.1304 - accuracy: 0.9614 - val_loss: 1.5116 - val_accuracy: 0.6592
# Epoch 25/50
# 156/156 [==============================] - 4s 23ms/step - loss: 0.1207 - accuracy: 0.9654 - val_loss: 1.5980 - val_accuracy: 0.6506
# Epoch 26/50
# 156/156 [==============================] - 4s 23ms/step - loss: 0.1133 - accuracy: 0.9686 - val_loss: 1.6473 - val_accuracy: 0.6368
# Epoch 27/50
# 156/156 [==============================] - 4s 23ms/step - loss: 0.1074 - accuracy: 0.9686 - val_loss: 1.7372 - val_accuracy: 0.6282
# Epoch 28/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.1020 - accuracy: 0.9702 - val_loss: 1.7137 - val_accuracy: 0.6303
# Epoch 29/50
# 156/156 [==============================] - 4s 25ms/step - loss: 0.0886 - accuracy: 0.9772 - val_loss: 1.7637 - val_accuracy: 0.6154
# Epoch 30/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.0900 - accuracy: 0.9741 - val_loss: 1.6692 - val_accuracy: 0.6282
# Epoch 31/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.0879 - accuracy: 0.9738 - val_loss: 1.8327 - val_accuracy: 0.6400
# Epoch 32/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.0826 - accuracy: 0.9752 - val_loss: 1.7223 - val_accuracy: 0.6506
# Epoch 33/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.0750 - accuracy: 0.9801 - val_loss: 1.7364 - val_accuracy: 0.6357
# Epoch 34/50
# 156/156 [==============================] - 4s 25ms/step - loss: 0.0745 - accuracy: 0.9792 - val_loss: 1.8766 - val_accuracy: 0.6335
# Epoch 35/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.0682 - accuracy: 0.9805 - val_loss: 1.9842 - val_accuracy: 0.6165
# Epoch 36/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.0628 - accuracy: 0.9815 - val_loss: 1.9891 - val_accuracy: 0.6410
# Epoch 37/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.0633 - accuracy: 0.9822 - val_loss: 2.2362 - val_accuracy: 0.6271
# Epoch 38/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.0527 - accuracy: 0.9864 - val_loss: 1.8606 - val_accuracy: 0.6421
# Epoch 39/50
# 156/156 [==============================] - 4s 23ms/step - loss: 0.0583 - accuracy: 0.9844 - val_loss: 2.0274 - val_accuracy: 0.6303
# Epoch 40/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.0480 - accuracy: 0.9878 - val_loss: 1.9356 - val_accuracy: 0.6314
# Epoch 41/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.0463 - accuracy: 0.9881 - val_loss: 1.9717 - val_accuracy: 0.6368
# Epoch 42/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.0503 - accuracy: 0.9867 - val_loss: 2.1186 - val_accuracy: 0.6165
# Epoch 43/50
# 156/156 [==============================] - 4s 23ms/step - loss: 0.0438 - accuracy: 0.9876 - val_loss: 2.1009 - val_accuracy: 0.6218
# Epoch 44/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.0408 - accuracy: 0.9886 - val_loss: 2.0150 - val_accuracy: 0.6250
# Epoch 45/50
# 156/156 [==============================] - 4s 25ms/step - loss: 0.0394 - accuracy: 0.9910 - val_loss: 2.0351 - val_accuracy: 0.6400
# Epoch 46/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.0388 - accuracy: 0.9901 - val_loss: 2.0386 - val_accuracy: 0.6410
# Epoch 47/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.0419 - accuracy: 0.9896 - val_loss: 2.1636 - val_accuracy: 0.6357
# Epoch 48/50
# 156/156 [==============================] - 4s 24ms/step - loss: 0.0380 - accuracy: 0.9896 - val_loss: 2.2618 - val_accuracy: 0.6346
# Epoch 49/50
# 156/156 [==============================] - 4s 25ms/step - loss: 0.0364 - accuracy: 0.9894 - val_loss: 2.1121 - val_accuracy: 0.6229
# Epoch 50/50
# 156/156 [==============================] - 4s 25ms/step - loss: 0.0356 - accuracy: 0.9909 - val_loss: 2.0433 - val_accuracy: 0.6485
# 30/30 [==============================] - 0s 5ms/step - loss: 2.0433 - accuracy: 0.6485
# Epoch 1/50
# 159/159 [==============================] - 4s 25ms/step - loss: 1.6502 - accuracy: 0.4566 - val_loss: 1.6239 - val_accuracy: 0.4168
# Epoch 2/50
# 159/159 [==============================] - 4s 24ms/step - loss: 1.1173 - accuracy: 0.6461 - val_loss: 1.4791 - val_accuracy: 0.4921
# Epoch 3/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.9064 - accuracy: 0.7169 - val_loss: 1.4678 - val_accuracy: 0.5310
# Epoch 4/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.7519 - accuracy: 0.7701 - val_loss: 1.3902 - val_accuracy: 0.5407
# Epoch 5/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.6522 - accuracy: 0.7974 - val_loss: 1.4123 - val_accuracy: 0.5492
# Epoch 6/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.5679 - accuracy: 0.8312 - val_loss: 1.3937 - val_accuracy: 0.5869
# Epoch 7/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.5076 - accuracy: 0.8470 - val_loss: 1.4078 - val_accuracy: 0.5844
# Epoch 8/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.4566 - accuracy: 0.8617 - val_loss: 1.3855 - val_accuracy: 0.5978
# Epoch 9/50
# 159/159 [==============================] - 4s 25ms/step - loss: 0.4123 - accuracy: 0.8770 - val_loss: 1.4621 - val_accuracy: 0.5905
# Epoch 10/50
# 159/159 [==============================] - 4s 25ms/step - loss: 0.3722 - accuracy: 0.8876 - val_loss: 1.4225 - val_accuracy: 0.5857
# Epoch 11/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.3386 - accuracy: 0.8975 - val_loss: 1.3984 - val_accuracy: 0.5954
# Epoch 12/50
# 159/159 [==============================] - 4s 25ms/step - loss: 0.3159 - accuracy: 0.9039 - val_loss: 1.4435 - val_accuracy: 0.6087
# Epoch 13/50
# 159/159 [==============================] - 4s 25ms/step - loss: 0.2868 - accuracy: 0.9157 - val_loss: 1.5098 - val_accuracy: 0.6015
# Epoch 14/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.2677 - accuracy: 0.9220 - val_loss: 1.4767 - val_accuracy: 0.6015
# Epoch 15/50
# 159/159 [==============================] - 4s 25ms/step - loss: 0.2488 - accuracy: 0.9246 - val_loss: 1.5149 - val_accuracy: 0.6051
# Epoch 16/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.2324 - accuracy: 0.9300 - val_loss: 1.5673 - val_accuracy: 0.5978
# Epoch 17/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.2144 - accuracy: 0.9373 - val_loss: 1.6125 - val_accuracy: 0.6002
# Epoch 18/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.1942 - accuracy: 0.9421 - val_loss: 1.5728 - val_accuracy: 0.5990
# Epoch 19/50
# 159/159 [==============================] - 4s 25ms/step - loss: 0.1821 - accuracy: 0.9446 - val_loss: 1.6367 - val_accuracy: 0.5942
# Epoch 20/50
# 159/159 [==============================] - 4s 25ms/step - loss: 0.1749 - accuracy: 0.9492 - val_loss: 1.6135 - val_accuracy: 0.5966
# Epoch 21/50
# 159/159 [==============================] - 4s 25ms/step - loss: 0.1572 - accuracy: 0.9528 - val_loss: 1.6628 - val_accuracy: 0.6112
# Epoch 22/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.1492 - accuracy: 0.9555 - val_loss: 1.6971 - val_accuracy: 0.5990
# Epoch 23/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.1446 - accuracy: 0.9568 - val_loss: 1.6687 - val_accuracy: 0.6112
# Epoch 24/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.1274 - accuracy: 0.9638 - val_loss: 1.7291 - val_accuracy: 0.6027
# Epoch 25/50
# 159/159 [==============================] - 4s 25ms/step - loss: 0.1203 - accuracy: 0.9642 - val_loss: 1.8153 - val_accuracy: 0.6063
# Epoch 26/50
# 159/159 [==============================] - 4s 25ms/step - loss: 0.1173 - accuracy: 0.9667 - val_loss: 1.9026 - val_accuracy: 0.5990
# Epoch 27/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.1082 - accuracy: 0.9698 - val_loss: 1.8680 - val_accuracy: 0.6100
# Epoch 28/50
# 159/159 [==============================] - 4s 25ms/step - loss: 0.1040 - accuracy: 0.9697 - val_loss: 1.9171 - val_accuracy: 0.5966
# Epoch 29/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.0978 - accuracy: 0.9724 - val_loss: 1.8694 - val_accuracy: 0.6087
# Epoch 30/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.0889 - accuracy: 0.9748 - val_loss: 1.9451 - val_accuracy: 0.6015
# Epoch 31/50
# 159/159 [==============================] - 4s 25ms/step - loss: 0.0787 - accuracy: 0.9764 - val_loss: 2.0031 - val_accuracy: 0.5990
# Epoch 32/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.0786 - accuracy: 0.9794 - val_loss: 2.0317 - val_accuracy: 0.6148
# Epoch 33/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.0779 - accuracy: 0.9771 - val_loss: 2.1129 - val_accuracy: 0.5954
# Epoch 34/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.0733 - accuracy: 0.9801 - val_loss: 2.0606 - val_accuracy: 0.6051
# Epoch 35/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.0659 - accuracy: 0.9823 - val_loss: 2.1978 - val_accuracy: 0.5881
# Epoch 36/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.0639 - accuracy: 0.9822 - val_loss: 2.1239 - val_accuracy: 0.6087
# Epoch 37/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.0540 - accuracy: 0.9866 - val_loss: 2.1868 - val_accuracy: 0.5930
# Epoch 38/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.0553 - accuracy: 0.9855 - val_loss: 2.2087 - val_accuracy: 0.6002
# Epoch 39/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.0535 - accuracy: 0.9863 - val_loss: 2.1779 - val_accuracy: 0.6124
# Epoch 40/50
# 159/159 [==============================] - 4s 23ms/step - loss: 0.0495 - accuracy: 0.9870 - val_loss: 2.1848 - val_accuracy: 0.5966
# Epoch 41/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.0510 - accuracy: 0.9861 - val_loss: 2.3425 - val_accuracy: 0.5723
# Epoch 42/50
# 159/159 [==============================] - 4s 25ms/step - loss: 0.0454 - accuracy: 0.9879 - val_loss: 2.3303 - val_accuracy: 0.5978
# Epoch 43/50
# 159/159 [==============================] - 4s 25ms/step - loss: 0.0445 - accuracy: 0.9880 - val_loss: 2.3310 - val_accuracy: 0.6002
# Epoch 44/50
# 159/159 [==============================] - 4s 25ms/step - loss: 0.0378 - accuracy: 0.9915 - val_loss: 2.2872 - val_accuracy: 0.5942
# Epoch 45/50
# 159/159 [==============================] - 4s 25ms/step - loss: 0.0396 - accuracy: 0.9893 - val_loss: 2.4289 - val_accuracy: 0.5990
# Epoch 46/50
# 159/159 [==============================] - 4s 25ms/step - loss: 0.0433 - accuracy: 0.9882 - val_loss: 2.3237 - val_accuracy: 0.5930
# Epoch 47/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.0417 - accuracy: 0.9887 - val_loss: 2.5087 - val_accuracy: 0.5990
# Epoch 48/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.0359 - accuracy: 0.9901 - val_loss: 2.3935 - val_accuracy: 0.6148
# Epoch 49/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.0334 - accuracy: 0.9909 - val_loss: 2.3867 - val_accuracy: 0.6087
# Epoch 50/50
# 159/159 [==============================] - 4s 24ms/step - loss: 0.0412 - accuracy: 0.9874 - val_loss: 2.4339 - val_accuracy: 0.6087
# 26/26 [==============================] - 0s 5ms/step - loss: 2.4339 - accuracy: 0.6087
# Epoch 1/50
# 158/158 [==============================] - 4s 25ms/step - loss: 1.6898 - accuracy: 0.4421 - val_loss: 1.3727 - val_accuracy: 0.5537
# Epoch 2/50
# 158/158 [==============================] - 4s 24ms/step - loss: 1.1328 - accuracy: 0.6488 - val_loss: 1.1137 - val_accuracy: 0.5871
# Epoch 3/50
# 158/158 [==============================] - 4s 24ms/step - loss: 0.8879 - accuracy: 0.7297 - val_loss: 0.9684 - val_accuracy: 0.6742
# Epoch 4/50
# 158/158 [==============================] - 4s 24ms/step - loss: 0.7359 - accuracy: 0.7769 - val_loss: 0.9170 - val_accuracy: 0.6993
# Epoch 5/50
# 158/158 [==============================] - 4s 24ms/step - loss: 0.6230 - accuracy: 0.8152 - val_loss: 0.8749 - val_accuracy: 0.6921
# Epoch 6/50
# 158/158 [==============================] - 4s 24ms/step - loss: 0.5412 - accuracy: 0.8334 - val_loss: 0.8529 - val_accuracy: 0.7100
# Epoch 7/50
# 158/158 [==============================] - 4s 25ms/step - loss: 0.4797 - accuracy: 0.8579 - val_loss: 0.8328 - val_accuracy: 0.7255
# Epoch 8/50
# 158/158 [==============================] - 4s 25ms/step - loss: 0.4278 - accuracy: 0.8747 - val_loss: 0.8454 - val_accuracy: 0.7088
# Epoch 9/50
# 158/158 [==============================] - 4s 25ms/step - loss: 0.3870 - accuracy: 0.8848 - val_loss: 0.8076 - val_accuracy: 0.7363
# Epoch 10/50
# 158/158 [==============================] - 4s 24ms/step - loss: 0.3480 - accuracy: 0.8955 - val_loss: 0.9172 - val_accuracy: 0.6981
# Epoch 11/50
# 158/158 [==============================] - 4s 24ms/step - loss: 0.3212 - accuracy: 0.9046 - val_loss: 0.9377 - val_accuracy: 0.6838
# Epoch 12/50
# 158/158 [==============================] - 4s 25ms/step - loss: 0.2901 - accuracy: 0.9122 - val_loss: 0.8560 - val_accuracy: 0.7208
# Epoch 13/50
# 158/158 [==============================] - 4s 24ms/step - loss: 0.2691 - accuracy: 0.9194 - val_loss: 0.9380 - val_accuracy: 0.6957
# Epoch 14/50
# 158/158 [==============================] - 4s 24ms/step - loss: 0.2416 - accuracy: 0.9278 - val_loss: 0.8336 - val_accuracy: 0.7351
# Epoch 15/50
# 158/158 [==============================] - 4s 25ms/step - loss: 0.2204 - accuracy: 0.9355 - val_loss: 0.8775 - val_accuracy: 0.7160
# Epoch 16/50
# 158/158 [==============================] - 4s 24ms/step - loss: 0.2069 - accuracy: 0.9387 - val_loss: 0.8830 - val_accuracy: 0.6790
# Epoch 17/50
# 158/158 [==============================] - 4s 24ms/step - loss: 0.1938 - accuracy: 0.9432 - val_loss: 0.8698 - val_accuracy: 0.6921
# Epoch 18/50
# 158/158 [==============================] - 4s 25ms/step - loss: 0.1783 - accuracy: 0.9501 - val_loss: 0.9437 - val_accuracy: 0.6897
# Epoch 19/50
# 158/158 [==============================] - 4s 24ms/step - loss: 0.1655 - accuracy: 0.9530 - val_loss: 0.9054 - val_accuracy: 0.7112
# Epoch 20/50
# 158/158 [==============================] - 4s 24ms/step - loss: 0.1477 - accuracy: 0.9568 - val_loss: 0.9771 - val_accuracy: 0.6885
# Epoch 21/50
# 158/158 [==============================] - 4s 25ms/step - loss: 0.1376 - accuracy: 0.9615 - val_loss: 0.9347 - val_accuracy: 0.6993
# Epoch 22/50
# 158/158 [==============================] - 4s 26ms/step - loss: 0.1283 - accuracy: 0.9644 - val_loss: 0.9753 - val_accuracy: 0.6921
# Epoch 23/50
# 158/158 [==============================] - 4s 25ms/step - loss: 0.1210 - accuracy: 0.9653 - val_loss: 0.9067 - val_accuracy: 0.6981
# Epoch 24/50
# 158/158 [==============================] - 4s 25ms/step - loss: 0.1134 - accuracy: 0.9678 - val_loss: 0.9597 - val_accuracy: 0.6921
# Epoch 25/50
# 158/158 [==============================] - 4s 25ms/step - loss: 0.1061 - accuracy: 0.9701 - val_loss: 0.9530 - val_accuracy: 0.7064
# Epoch 26/50
# 158/158 [==============================] - 4s 25ms/step - loss: 0.0989 - accuracy: 0.9704 - val_loss: 1.0144 - val_accuracy: 0.7053
# ...
# Epoch 42/50
# 159/159 [==============================] - 3s 20ms/step - loss: 0.0465 - accuracy: 0.9880 - val_loss: 2.1688 - val_accuracy: 0.5794
# Epoch 43/50
# 159/159 [==============================] - 3s 21ms/step - loss: 0.0487 - accuracy: 0.9868 - val_loss: 2.2747 - val_accuracy: 0.5806
# Epoch 44/50
# 159/159 [==============================] - 3s 21ms/step - loss: 0.0437 - accuracy: 0.9890 - val_loss: 2.2724 - val_accuracy: 0.5993
# Epoch 45/50
# 159/159 [==============================] - 3s 21ms/step - loss: 0.0378 - accuracy: 0.9908 - val_loss: 2.1279 - val_accuracy: 0.5881
# Epoch 46/50
# 159/159 [==============================] - 3s 21ms/step - loss: 0.0410 - accuracy: 0.9883 - val_loss: 2.1495 - val_accuracy: 0.5707
# Epoch 47/50
# 159/159 [==============================] - 3s 21ms/step - loss: 0.0389 - accuracy: 0.9904 - val_loss: 2.0742 - val_accuracy: 0.5881
# Epoch 48/50
# 159/159 [==============================] - 3s 21ms/step - loss: 0.0384 - accuracy: 0.9886 - val_loss: 2.4459 - val_accuracy: 0.5782
# Epoch 49/50
# 159/159 [==============================] - 3s 21ms/step - loss: 0.0358 - accuracy: 0.9913 - val_loss: 2.2648 - val_accuracy: 0.6030
# Epoch 50/50
# 159/159 [==============================] - 3s 21ms/step - loss: 0.0371 - accuracy: 0.9907 - val_loss: 2.4293 - val_accuracy: 0.5980
# 26/26 [==============================] - 0s 4ms/step - loss: 2.4293 - accuracy: 0.5980
# Epoch 1/50
# 159/159 [==============================] - 4s 21ms/step - loss: 1.6524 - accuracy: 0.4569 - val_loss: 1.4354 - val_accuracy: 0.5306
# Epoch 2/50
# 159/159 [==============================] - 3s 20ms/step - loss: 1.1328 - accuracy: 0.6427 - val_loss: 1.2410 - val_accuracy: 0.6140
# Epoch 3/50
# 159/159 [==============================] - 3s 20ms/step - loss: 0.9003 - accuracy: 0.7191 - val_loss: 1.1713 - val_accuracy: 0.6250
# Epoch 4/50
# 159/159 [==============================] - 3s 21ms/step - loss: 0.7479 - accuracy: 0.7761 - val_loss: 1.1775 - val_accuracy: 0.6520
# Epoch 5/50
# 159/159 [==============================] - 3s 21ms/step - loss: 0.6376 - accuracy: 0.8032 - val_loss: 1.0611 - val_accuracy: 0.6728
# Epoch 6/50
# 159/159 [==============================] - 3s 20ms/step - loss: 0.5523 - accuracy: 0.8359 - val_loss: 1.0783 - val_accuracy: 0.6973
# Epoch 7/50
# 159/159 [==============================] - 3s 21ms/step - loss: 0.4969 - accuracy: 0.8511 - val_loss: 1.1314 - val_accuracy: 0.6838
# Epoch 8/50
# 159/159 [==============================] - 3s 20ms/step - loss: 0.4401 - accuracy: 0.8705 - val_loss: 1.1874 - val_accuracy: 0.6912
# Epoch 9/50
# 159/159 [==============================] - 3s 20ms/step - loss: 0.4019 - accuracy: 0.8780 - val_loss: 1.1855 - val_accuracy: 0.6642
# Epoch 10/50
# 159/159 [==============================] - 3s 20ms/step - loss: 0.3699 - accuracy: 0.8901 - val_loss: 1.2084 - val_accuracy: 0.6679
# Epoch 11/50
# 159/159 [==============================] - 3s 21ms/step - loss: 0.3335 - accuracy: 0.8981 - val_loss: 1.2538 - val_accuracy: 0.6581
# Epoch 12/50
# 159/159 [==============================] - 3s 21ms/step - loss: 0.3030 - accuracy: 0.9106 - val_loss: 1.2400 - val_accuracy: 0.6863
# Epoch 13/50
# 159/159 [==============================] - 3s 20ms/step - loss: 0.2784 - accuracy: 0.9174 - val_loss: 1.3039 - val_accuracy: 0.6691
# Epoch 14/50
# 159/159 [==============================] - 3s 21ms/step - loss: 0.2564 - accuracy: 0.9229 - val_loss: 1.2874 - val_accuracy: 0.6728
# Epoch 15/50
# 159/159 [==============================] - 3s 20ms/step - loss: 0.2382 - accuracy: 0.9253 - val_loss: 1.4209 - val_accuracy: 0.6581
# Epoch 16/50
# 159/159 [==============================] - 3s 21ms/step - loss: 0.2160 - accuracy: 0.9366 - val_loss: 1.5127 - val_accuracy: 0.6556
# Epoch 17/50
# 159/159 [==============================] - 3s 20ms/step - loss: 0.2095 - accuracy: 0.9376 - val_loss: 1.4606 - val_accuracy: 0.6752
# Epoch 18/50
# 159/159 [==============================] - 3s 21ms/step - loss: 0.1886 - accuracy: 0.9450 - val_loss: 1.4064 - val_accuracy: 0.6789
# Epoch 19/50
# 159/159 [==============================] - 3s 20ms/step - loss: 0.1751 - accuracy: 0.9486 - val_loss: 1.6062 - val_accuracy: 0.6569
# Epoch 20/50
# 159/159 [==============================] - 3s 20ms/step - loss: 0.1656 - accuracy: 0.9510 - val_loss: 1.4968 - val_accuracy: 0.6789
# Epoch 21/50
# 159/159 [==============================] - 3s 20ms/step - loss: 0.1515 - accuracy: 0.9567 - val_loss: 1.6611 - val_accuracy: 0.6556
# Epoch 22/50
# 159/159 [==============================] - 3s 20ms/step - loss: 0.1453 - accuracy: 0.9554 - val_loss: 1.6825 - val_accuracy: 0.6618
# Epoch 23/50
# 159/159 [==============================] - 3s 20ms/step - loss: 0.1277 - accuracy: 0.9621 - val_loss: 1.7850 - val_accuracy: 0.6385
# Epoch 24/50
# 159/159 [==============================] - 3s 20ms/step - loss: 0.1198 - accuracy: 0.9666 - val_loss: 1.6741 - val_accuracy: 0.6642
# Epoch 25/50
# 159/159 [==============================] - 3s 21ms/step - loss: 0.1132 - accuracy: 0.9683 - val_loss: 1.8524 - val_accuracy: 0.6703
# Epoch 26/50
# 159/159 [==============================] - 3s 20ms/step - loss: 0.1063 - accuracy: 0.9699 - val_loss: 1.8175 - val_accuracy: 0.6458
# Epoch 27/50
# 159/159 [==============================] - 3s 20ms/step - loss: 0.1036 - accuracy: 0.9715 - val_loss: 1.8423 - val_accuracy: 0.6544
# Epoch 28/50
# 159/159 [==============================] - 3s 21ms/step - loss: 0.0982 - accuracy: 0.9727 - val_loss: 1.8978 - val_accuracy: 0.6691
# Epoch 29/50
# 159/159 [==============================] - 3s 21ms/step - loss: 0.0872 - accuracy: 0.9763 - val_loss: 1.7880 - val_accuracy: 0.6716
# Epoch 30/50
# 159/159 [==============================] - 3s 20ms/step - loss: 0.0832 - accuracy: 0.9774 - val_loss: 1.8401 - val_accuracy: 0.6654
# Epoch 31/50
# 159/159 [==============================] - 3s 20ms/step - loss: 0.0725 - accuracy: 0.9813 - val_loss: 1.9261 - val_accuracy: 0.6262
# Epoch 32/50
# 159/159 [==============================] - 3s 20ms/step - loss: 0.0756 - accuracy: 0.9790 - val_loss: 1.9891 - val_accuracy: 0.6532
# Epoch 33/50
# 159/159 [==============================] - 3s 20ms/step - loss: 0.0666 - accuracy: 0.9813 - val_loss: 2.1500 - val_accuracy: 0.6654
# Epoch 34/50
# 159/159 [==============================] - 3s 20ms/step - loss: 0.0654 - accuracy: 0.9816 - val_loss: 1.9719 - val_accuracy: 0.6667
# Epoch 35/50
# 159/159 [==============================] - 3s 20ms/step - loss: 0.0590 - accuracy: 0.9846 - val_loss: 2.0052 - val_accuracy: 0.6507
# Epoch 36/50
# 159/159 [==============================] - 3s 20ms/step - loss: 0.0614 - accuracy: 0.9838 - val_loss: 2.2570 - val_accuracy: 0.6605
# Epoch 37/50
# 159/159 [==============================] - 3s 20ms/step - loss: 0.0540 - accuracy: 0.9853 - val_loss: 2.0193 - val_accuracy: 0.6556
# Epoch 38/50
# 159/159 [==============================] - 3s 20ms/step - loss: 0.0537 - accuracy: 0.9859 - val_loss: 2.1436 - val_accuracy: 0.6556
# Epoch 39/50
# 159/159 [==============================] - 3s 20ms/step - loss: 0.0448 - accuracy: 0.9885 - val_loss: 2.2545 - val_accuracy: 0.6520
# Epoch 40/50
# 159/159 [==============================] - 3s 20ms/step - loss: 0.0438 - accuracy: 0.9896 - val_loss: 2.2493 - val_accuracy: 0.6556
# Epoch 41/50
# 159/159 [==============================] - 3s 22ms/step - loss: 0.0400 - accuracy: 0.9914 - val_loss: 2.2325 - val_accuracy: 0.6458
# Epoch 42/50
# 159/159 [==============================] - 4s 22ms/step - loss: 0.0449 - accuracy: 0.9891 - val_loss: 2.2716 - val_accuracy: 0.6397
# Epoch 43/50
# 159/159 [==============================] - 3s 21ms/step - loss: 0.0389 - accuracy: 0.9899 - val_loss: 2.3923 - val_accuracy: 0.6373
# Epoch 44/50
# 159/159 [==============================] - 3s 21ms/step - loss: 0.0448 - accuracy: 0.9879 - val_loss: 2.3589 - val_accuracy: 0.6532
# Epoch 45/50
# 159/159 [==============================] - 3s 21ms/step - loss: 0.0401 - accuracy: 0.9896 - val_loss: 2.5075 - val_accuracy: 0.6471
# Epoch 46/50
# 159/159 [==============================] - 3s 21ms/step - loss: 0.0334 - accuracy: 0.9924 - val_loss: 2.4457 - val_accuracy: 0.6483
# Epoch 47/50
# 159/159 [==============================] - 3s 22ms/step - loss: 0.0357 - accuracy: 0.9915 - val_loss: 2.7243 - val_accuracy: 0.6507
# Epoch 48/50
# 159/159 [==============================] - 3s 22ms/step - loss: 0.0299 - accuracy: 0.9925 - val_loss: 2.5763 - val_accuracy: 0.6532
# Epoch 49/50
# 159/159 [==============================] - 3s 21ms/step - loss: 0.0308 - accuracy: 0.9919 - val_loss: 2.4936 - val_accuracy: 0.6311
# Epoch 50/50
# 159/159 [==============================] - 3s 21ms/step - loss: 0.0345 - accuracy: 0.9914 - val_loss: 2.6679 - val_accuracy: 0.6703
# 26/26 [==============================] - 0s 4ms/step - loss: 2.6679 - accuracy: 0.6703
# Epoch 1/50
# 158/158 [==============================] - 4s 22ms/step - loss: 1.6284 - accuracy: 0.4638 - val_loss: 1.3367 - val_accuracy: 0.5854
# Epoch 2/50
# 158/158 [==============================] - 3s 21ms/step - loss: 1.0990 - accuracy: 0.6509 - val_loss: 1.1291 - val_accuracy: 0.6368
# Epoch 3/50
# 158/158 [==============================] - 4s 22ms/step - loss: 0.8766 - accuracy: 0.7293 - val_loss: 1.0556 - val_accuracy: 0.6428
# Epoch 4/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.7283 - accuracy: 0.7788 - val_loss: 1.0017 - val_accuracy: 0.6631
# Epoch 5/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.6243 - accuracy: 0.8104 - val_loss: 0.9555 - val_accuracy: 0.6559
# Epoch 6/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.5470 - accuracy: 0.8333 - val_loss: 0.9511 - val_accuracy: 0.6679
# Epoch 7/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.4844 - accuracy: 0.8550 - val_loss: 0.9857 - val_accuracy: 0.6691
# Epoch 8/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.4409 - accuracy: 0.8617 - val_loss: 0.9511 - val_accuracy: 0.6679
# Epoch 9/50
# 158/158 [==============================] - 4s 23ms/step - loss: 0.3938 - accuracy: 0.8804 - val_loss: 0.9735 - val_accuracy: 0.6607
# Epoch 10/50
# 158/158 [==============================] - 3s 22ms/step - loss: 0.3572 - accuracy: 0.8887 - val_loss: 0.9916 - val_accuracy: 0.6858
# Epoch 11/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.3274 - accuracy: 0.9013 - val_loss: 0.9882 - val_accuracy: 0.6774
# Epoch 12/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.3044 - accuracy: 0.9050 - val_loss: 1.0327 - val_accuracy: 0.6583
# Epoch 13/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.2755 - accuracy: 0.9167 - val_loss: 1.0759 - val_accuracy: 0.6583
# Epoch 14/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.2555 - accuracy: 0.9218 - val_loss: 1.1073 - val_accuracy: 0.6703
# Epoch 15/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.2391 - accuracy: 0.9267 - val_loss: 1.1004 - val_accuracy: 0.6511
# Epoch 16/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.2163 - accuracy: 0.9360 - val_loss: 1.1586 - val_accuracy: 0.6416
# Epoch 17/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.2010 - accuracy: 0.9408 - val_loss: 1.0554 - val_accuracy: 0.6703
# Epoch 18/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.1894 - accuracy: 0.9406 - val_loss: 1.1254 - val_accuracy: 0.6571
# Epoch 19/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.1754 - accuracy: 0.9462 - val_loss: 1.1155 - val_accuracy: 0.6631
# Epoch 20/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.1711 - accuracy: 0.9476 - val_loss: 1.2116 - val_accuracy: 0.6571
# Epoch 21/50
# 158/158 [==============================] - 3s 22ms/step - loss: 0.1540 - accuracy: 0.9553 - val_loss: 1.1530 - val_accuracy: 0.6667
# Epoch 22/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.1356 - accuracy: 0.9616 - val_loss: 1.2083 - val_accuracy: 0.6619
# Epoch 23/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.1264 - accuracy: 0.9650 - val_loss: 1.1714 - val_accuracy: 0.6476
# Epoch 24/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.1228 - accuracy: 0.9655 - val_loss: 1.2302 - val_accuracy: 0.6691
# Epoch 25/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.1186 - accuracy: 0.9667 - val_loss: 1.2981 - val_accuracy: 0.6726
# Epoch 26/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.1164 - accuracy: 0.9668 - val_loss: 1.3437 - val_accuracy: 0.6380
# Epoch 27/50
# 158/158 [==============================] - 3s 20ms/step - loss: 0.1004 - accuracy: 0.9721 - val_loss: 1.3461 - val_accuracy: 0.6440
# Epoch 28/50
# 158/158 [==============================] - 3s 20ms/step - loss: 0.0959 - accuracy: 0.9742 - val_loss: 1.3234 - val_accuracy: 0.6380
# Epoch 29/50
# 158/158 [==============================] - 3s 20ms/step - loss: 0.0921 - accuracy: 0.9734 - val_loss: 1.2964 - val_accuracy: 0.6667
# Epoch 30/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.0844 - accuracy: 0.9773 - val_loss: 1.3037 - val_accuracy: 0.6476
# Epoch 31/50
# 158/158 [==============================] - 3s 20ms/step - loss: 0.0788 - accuracy: 0.9771 - val_loss: 1.2770 - val_accuracy: 0.6726
# Epoch 32/50
# 158/158 [==============================] - 3s 20ms/step - loss: 0.0756 - accuracy: 0.9795 - val_loss: 1.3421 - val_accuracy: 0.6476
# Epoch 33/50
# 158/158 [==============================] - 3s 20ms/step - loss: 0.0720 - accuracy: 0.9816 - val_loss: 1.3492 - val_accuracy: 0.6547
# Epoch 34/50
# 158/158 [==============================] - 3s 20ms/step - loss: 0.0658 - accuracy: 0.9818 - val_loss: 1.4240 - val_accuracy: 0.6380
# Epoch 35/50
# 158/158 [==============================] - 3s 20ms/step - loss: 0.0643 - accuracy: 0.9823 - val_loss: 1.4192 - val_accuracy: 0.6571
# Epoch 36/50
# 158/158 [==============================] - 4s 22ms/step - loss: 0.0627 - accuracy: 0.9825 - val_loss: 1.5255 - val_accuracy: 0.6452
# Epoch 37/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.0623 - accuracy: 0.9809 - val_loss: 1.4344 - val_accuracy: 0.6691
# Epoch 38/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.0563 - accuracy: 0.9845 - val_loss: 1.4872 - val_accuracy: 0.6571
# Epoch 39/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.0550 - accuracy: 0.9842 - val_loss: 1.3360 - val_accuracy: 0.6846
# Epoch 40/50
# 158/158 [==============================] - 3s 20ms/step - loss: 0.0497 - accuracy: 0.9863 - val_loss: 1.4889 - val_accuracy: 0.6499
# Epoch 41/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.0460 - accuracy: 0.9875 - val_loss: 1.6249 - val_accuracy: 0.6380
# Epoch 42/50
# 158/158 [==============================] - 3s 20ms/step - loss: 0.0444 - accuracy: 0.9887 - val_loss: 1.5489 - val_accuracy: 0.6511
# Epoch 43/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.0398 - accuracy: 0.9901 - val_loss: 1.4664 - val_accuracy: 0.6476
# Epoch 44/50
# 158/158 [==============================] - 3s 20ms/step - loss: 0.0403 - accuracy: 0.9908 - val_loss: 1.6041 - val_accuracy: 0.6523
# Epoch 45/50
# 158/158 [==============================] - 3s 20ms/step - loss: 0.0396 - accuracy: 0.9895 - val_loss: 1.6574 - val_accuracy: 0.6499
# Epoch 46/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.0416 - accuracy: 0.9886 - val_loss: 1.6774 - val_accuracy: 0.6535
# Epoch 47/50
# 158/158 [==============================] - 4s 22ms/step - loss: 0.0359 - accuracy: 0.9909 - val_loss: 1.6407 - val_accuracy: 0.6559
# Epoch 48/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.0350 - accuracy: 0.9910 - val_loss: 1.7458 - val_accuracy: 0.6535
# Epoch 49/50
# 158/158 [==============================] - 3s 21ms/step - loss: 0.0338 - accuracy: 0.9914 - val_loss: 1.6984 - val_accuracy: 0.6416
# Epoch 50/50
# 158/158 [==============================] - 3s 22ms/step - loss: 0.0314 - accuracy: 0.9911 - val_loss: 1.6957 - val_accuracy: 0.6476
# 27/27 [==============================] - 0s 4ms/step - loss: 1.6957 - accuracy: 0.6476

# %% [markdown]
# Above is a model that is mirroring AlexNet. Testing to see how well it performs with several features. In the other notebook, `categorical_crossentropy` is used, but in this notebook, I didn't change the Dependent variable into a one-hot-encoder matrix, so I am using `sparce_categorical_crossentropy` which accounts for this difference in the data.
#
# In future iterations, I may change the the number of features in the filters, or perhaps use the tanh activation function at the end before `softmax` as this seemed to perform well in our first model (which is in the other notebook) which used only one feature.

# %%
fold_acc = pd.DataFrame(list(zip(range(1,11), accuracies)),
                        columns =['Folds', 'Validation Accuracy']) 

fold_acc
# Out:
#    Folds  Validation Accuracy
# 0      1             0.561283
# 1      2             0.604730
# 2      3             0.527568
# 3      4             0.632323
# 4      5             0.648504
# 5      6             0.608748
# 6      7             0.689737
# 7      8             0.598015
# 8      9             0.670343
# 9     10             0.647551

# %%
fold_acc["Validation Accuracy"].mean()
# Out:
# 0.6188802480697632

# %% [markdown]
# Below are a few helper functions in case we want to extract features over certain windows or implement a 10 fold crossvalidation.
#
# Resouces used:
#  - https://github.com/AmritK10/Urban-Sound-Classification
#  - https://www.kaggle.com/code/vortexkol/alexnet-cnn-architecture-on-tensorflow-beginner?scriptVersionId=43150351&cellId=21

# %%
### Define convolutional network architecture ###
def get_network():
    num_filters = [24,32,64,128] 
    pool_size = (2, 2) 
    kernel_size = (3, 3)  
    input_shape = (60, 41, 2)
    num_classes = 10
    keras.backend.clear_session()
    
    model = keras.models.Sequential()
    model.add(keras.layers.Conv2D(24, kernel_size,
                padding="same", input_shape=input_shape))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Activation("relu"))
    model.add(keras.layers.MaxPooling2D(pool_size=pool_size))

    model.add(keras.layers.Conv2D(32, kernel_size,
                                  padding="same"))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Activation("relu"))  
    model.add(keras.layers.MaxPooling2D(pool_size=pool_size))
    
    model.add(keras.layers.Conv2D(64, kernel_size,
                                  padding="same"))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Activation("relu"))  
    model.add(keras.layers.MaxPooling2D(pool_size=pool_size))
    
    model.add(keras.layers.Conv2D(128, kernel_size,
                                  padding="same"))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Activation("relu"))  

    model.add(keras.layers.GlobalMaxPooling2D())
    model.add(keras.layers.Dense(128, activation="relu"))
    model.add(keras.layers.Dense(num_classes, activation="softmax"))

    model.compile(optimizer=keras.optimizers.Adam(1e-4), 
        loss=keras.losses.SparseCategoricalCrossentropy(), 
        metrics=["accuracy"])
    return model

# %%
### Train and evaluate via 10-Folds cross-validation ###
accuracies = []
folds = np.array(['fold1','fold2','fold3','fold4',
                  'fold5','fold6','fold7','fold8',
                  'fold9','fold10'])
load_dir = "UrbanSounds8K/processed/"
kf = KFold(n_splits=10)
for train_index, test_index in kf.split(folds):
    x_train, y_train = [], []
    for ind in train_index:
        # read features or segments of an audio file
        train_data = np.load("{0}/{1}.npz".format(load_dir,folds[ind]), 
                       allow_pickle=True)
        # for training stack all the segments so that they are treated as an example/instance
        features = np.concatenate(train_data["features"], axis=0) 
        labels = np.concatenate(train_data["labels"], axis=0)
        x_train.append(features)
        y_train.append(labels)
    # stack x,y pairs of all training folds 
    x_train = np.concatenate(x_train, axis = 0).astype(np.float32)
    y_train = np.concatenate(y_train, axis = 0).astype(np.float32)
    
    # for testing we will make predictions on each segment and average them to 
    # produce signle label for an entire sound clip.
    test_data = np.load("{0}/{1}.npz".format(load_dir,
                   folds[test_index][0]), allow_pickle=True)
    x_test = test_data["features"]
    y_test = test_data["labels"]

    model = get_network()
    model.fit(x_train, y_train, epochs = 50, batch_size = 24, verbose = 0)
    
    # evaluate on test set/fold
    y_true, y_pred = [], []
    for x, y in zip(x_test, y_test):
        # average predictions over segments of a sound clip
        avg_p = np.argmax(np.mean(model.predict(x), axis = 0))
        y_pred.append(avg_p) 
        # pick single label via np.unique for a sound clip
        y_true.append(np.unique(y)[0]) 
    accuracies.append(accuracy_score(y_true, y_pred))    
print("Average 10 Folds Accuracy: {0}".format(np.mean(accuracies)))
